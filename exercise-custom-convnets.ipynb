# %% [markdown]
# <a href="https://www.kaggle.com/code/an1ndya/exercise-custom-convnets?scriptVersionId=160250173" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/custom-convnets).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In these exercises, you'll build a custom convnet with performance competitive to the VGG16 model from Lesson 1.
#
# Get started by running the code cell below.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex5 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# # Design a Convnet #
#
# Let's design a convolutional network with a block architecture like we saw in the tutorial. The model from the example had three blocks, each with a single convolutional layer. Its performance on the "Car or Truck" problem was okay, but far from what the pretrained VGG16 could achieve. It might be that our simple network lacks the ability to extract sufficiently complex features. We could try improving the model either by adding more blocks or by adding convolutions to the blocks we have.
#
# Let's go with the second approach. We'll keep the three block structure, but increase the number of `Conv2D` layer in the second block to two, and in the third block to three.
#
# <figure>
# <!-- <img src="./images/2-convmodel-2.png" width="250" alt="Diagram of a convolutional model."> -->
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/Vko6nCK.png" width="250" alt="Diagram of a convolutional model.">
# </figure>
#
# # 1) Define Model #
#
# Given the diagram above, complete the model by defining the layers of the third block.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape=[128, 128, 3]),
    layers.MaxPool2D(),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    # YOUR CODE HERE
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Head
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
q_1.hint()
q_1.solution()
# Out:
# Hint: You should add two `Conv2D` layers and then a `MaxPool2D` layer. They will be just the same as the other layers in the model, except for some of the parameter values.
# Solution:
# ```python
#
# from tensorflow import keras
# from tensorflow.keras import layers
#
# model = keras.Sequential([
#     # Block One
#     layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
#                   input_shape=[128, 128, 3]),
#     layers.MaxPool2D(),
#
#     # Block Two
#     layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
#     layers.MaxPool2D(),
#
#     # Block Three
#     layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
#     layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
#     layers.MaxPool2D(),
#
#     # Head
#     layers.Flatten(),
#     layers.Dense(6, activation='relu'),
#     layers.Dropout(0.2),
#     layers.Dense(1, activation='sigmoid'),
# ])
#
# ```

# %% [markdown]
# # 2) Compile #
#
# To prepare for training, compile the model with an appropriate loss and accuracy metric for the "Car or Truck" dataset.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    # YOUR CODE HERE: Add loss and metric
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
q_2.assert_check_passed()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
q_2.hint()
q_2.solution()
# Out:
# Hint: This is a *binary* classification problem.
# Solution:
# ```python
#
# model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
#     loss='binary_crossentropy',
#     metrics=['binary_accuracy'],
# )
#
# ```

# %% [markdown]
# Finally, let's test the performance of this new model. First run this cell to fit the model to the training set.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 16s 142ms/step - loss: 0.6920 - binary_accuracy: 0.5652 - val_loss: 0.6903 - val_binary_accuracy: 0.5785
# Epoch 2/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6888 - binary_accuracy: 0.5796 - val_loss: 0.6868 - val_binary_accuracy: 0.5858
# Epoch 3/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6843 - binary_accuracy: 0.5988 - val_loss: 0.6826 - val_binary_accuracy: 0.5900
# Epoch 4/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6791 - binary_accuracy: 0.6117 - val_loss: 0.6735 - val_binary_accuracy: 0.6411
# Epoch 5/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6719 - binary_accuracy: 0.6246 - val_loss: 0.6674 - val_binary_accuracy: 0.6474
# Epoch 6/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6669 - binary_accuracy: 0.6258 - val_loss: 0.6616 - val_binary_accuracy: 0.6527
# Epoch 7/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6595 - binary_accuracy: 0.6412 - val_loss: 0.6565 - val_binary_accuracy: 0.6547
# Epoch 8/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6526 - binary_accuracy: 0.6512 - val_loss: 0.6466 - val_binary_accuracy: 0.6654
# Epoch 9/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6422 - binary_accuracy: 0.6648 - val_loss: 0.6386 - val_binary_accuracy: 0.6787
# Epoch 10/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6356 - binary_accuracy: 0.6705 - val_loss: 0.6350 - val_binary_accuracy: 0.6751
# Epoch 11/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6277 - binary_accuracy: 0.6824 - val_loss: 0.6203 - val_binary_accuracy: 0.6910
# Epoch 12/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6146 - binary_accuracy: 0.6949 - val_loss: 0.6161 - val_binary_accuracy: 0.6965
# Epoch 13/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6110 - binary_accuracy: 0.6897 - val_loss: 0.6185 - val_binary_accuracy: 0.6872
# Epoch 14/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5956 - binary_accuracy: 0.7100 - val_loss: 0.6050 - val_binary_accuracy: 0.7040
# Epoch 15/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5835 - binary_accuracy: 0.7213 - val_loss: 0.6054 - val_binary_accuracy: 0.6981
# Epoch 16/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5765 - binary_accuracy: 0.7223 - val_loss: 0.5725 - val_binary_accuracy: 0.7335
# Epoch 17/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5682 - binary_accuracy: 0.7299 - val_loss: 0.5656 - val_binary_accuracy: 0.7399
# Epoch 18/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5416 - binary_accuracy: 0.7571 - val_loss: 0.5451 - val_binary_accuracy: 0.7551
# Epoch 19/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5240 - binary_accuracy: 0.7680 - val_loss: 0.5406 - val_binary_accuracy: 0.7563
# Epoch 20/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5120 - binary_accuracy: 0.7766 - val_loss: 0.5316 - val_binary_accuracy: 0.7610
# Epoch 21/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5016 - binary_accuracy: 0.7846 - val_loss: 0.5371 - val_binary_accuracy: 0.7537
# Epoch 22/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4979 - binary_accuracy: 0.7821 - val_loss: 0.5156 - val_binary_accuracy: 0.7701
# Epoch 23/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4691 - binary_accuracy: 0.8075 - val_loss: 0.5324 - val_binary_accuracy: 0.7589
# Epoch 24/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4629 - binary_accuracy: 0.8067 - val_loss: 0.4953 - val_binary_accuracy: 0.7884
# Epoch 25/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4429 - binary_accuracy: 0.8181 - val_loss: 0.4968 - val_binary_accuracy: 0.7810
# Epoch 26/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4162 - binary_accuracy: 0.8362 - val_loss: 0.4859 - val_binary_accuracy: 0.7943
# Epoch 27/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4098 - binary_accuracy: 0.8372 - val_loss: 0.4949 - val_binary_accuracy: 0.7967
# Epoch 28/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4010 - binary_accuracy: 0.8440 - val_loss: 0.4860 - val_binary_accuracy: 0.7998
# Epoch 29/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.3922 - binary_accuracy: 0.8474 - val_loss: 0.4743 - val_binary_accuracy: 0.8050
# Epoch 30/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4097 - binary_accuracy: 0.8355 - val_loss: 0.4959 - val_binary_accuracy: 0.7965
# Epoch 31/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3914 - binary_accuracy: 0.8464 - val_loss: 0.5089 - val_binary_accuracy: 0.8034
# Epoch 32/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4182 - binary_accuracy: 0.8270 - val_loss: 0.4836 - val_binary_accuracy: 0.7994
# Epoch 33/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3888 - binary_accuracy: 0.8474 - val_loss: 0.4599 - val_binary_accuracy: 0.8097
# Epoch 34/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3862 - binary_accuracy: 0.8468 - val_loss: 0.4835 - val_binary_accuracy: 0.7866
# Epoch 35/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3818 - binary_accuracy: 0.8497 - val_loss: 0.5038 - val_binary_accuracy: 0.7701
# Epoch 36/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3652 - binary_accuracy: 0.8597 - val_loss: 0.4711 - val_binary_accuracy: 0.7949
# Epoch 37/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3506 - binary_accuracy: 0.8702 - val_loss: 0.4361 - val_binary_accuracy: 0.8264
# Epoch 38/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3472 - binary_accuracy: 0.8700 - val_loss: 0.4744 - val_binary_accuracy: 0.8163
# Epoch 39/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.3508 - binary_accuracy: 0.8673 - val_loss: 0.4400 - val_binary_accuracy: 0.8212
# Epoch 40/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3557 - binary_accuracy: 0.8616 - val_loss: 0.5283 - val_binary_accuracy: 0.8022
# Epoch 41/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3081 - binary_accuracy: 0.8908 - val_loss: 0.4733 - val_binary_accuracy: 0.8333
# Epoch 42/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2641 - binary_accuracy: 0.9183 - val_loss: 0.4608 - val_binary_accuracy: 0.8384
# Epoch 43/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2362 - binary_accuracy: 0.9296 - val_loss: 0.5135 - val_binary_accuracy: 0.8373
# Epoch 44/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2130 - binary_accuracy: 0.9441 - val_loss: 0.5334 - val_binary_accuracy: 0.8313
# Epoch 45/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1970 - binary_accuracy: 0.9478 - val_loss: 0.5385 - val_binary_accuracy: 0.8400
# Epoch 46/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1736 - binary_accuracy: 0.9621 - val_loss: 0.4941 - val_binary_accuracy: 0.8424
# Epoch 47/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1641 - binary_accuracy: 0.9658 - val_loss: 0.5909 - val_binary_accuracy: 0.8361
# Epoch 48/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1534 - binary_accuracy: 0.9674 - val_loss: 0.5577 - val_binary_accuracy: 0.8402
# Epoch 49/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1444 - binary_accuracy: 0.9719 - val_loss: 0.4877 - val_binary_accuracy: 0.8422
# Epoch 50/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1462 - binary_accuracy: 0.9699 - val_loss: 0.5156 - val_binary_accuracy: 0.8533

# %% [markdown]
# And now run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 3) Train the Model #
#
# How would you interpret these training curves? Did this model improve upon the model from the tutorial?

# %%
# View the solution (Run this code cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
#
# The learning curves for the model from the tutorial diverged fairly rapidly. This would indicate that it was prone to overfitting and in need of some regularization. The additional layer in our new model would make it even more prone to overfitting. However, adding some regularization with the `Dropout` layer helped prevent this. These changes improved the validation accuracy of the model by several points.

# %% [markdown]
# # Conclusion #
#
# These exercises showed you how to design a custom convolutional network to solve a specific classification problem. Though most models these days will be built on top of a pretrained base, it certain circumstances a smaller custom convnet might still be preferable -- such as with a smaller or unusual dataset or when computing resources are very limited. As you saw here, for certain problems they can perform just as well as a pretrained model.
#
# # Keep Going #
#
# Continue on to [**Lesson 6**](https://www.kaggle.com/ryanholbrook/data-augmentation), where you'll learn a widely-used technique that can give a boost to your training data: **data augmentation**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
